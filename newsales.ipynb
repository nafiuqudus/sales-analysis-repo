# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales = pd.read_csv('sales_data.csv', index_col = 0)
sales
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
# ...         ...       ...   ...           ...             ...             ...
# 2016-04-12   12     April  2016            41  Adults (35-64)               M
# 2014-04-02    2     April  2014            18     Youth (<25)               M
# 2016-04-02    2     April  2016            18     Youth (<25)               M
# 2014-03-04    4     March  2014            37  Adults (35-64)               F
# 2016-03-04    4     March  2016            37  Adults (35-64)               F
#
# ...

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
sales.shape
# Out:
# (113036, 17)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113036 entries, 2013-11-26 to 2016-03-04
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Day               113036 non-null  int64
#  1   Month             113036 non-null  object
#  2   Year              113036 non-null  int64
#  3   Customer_Age      113036 non-null  int64
#  4   Age_Group         113036 non-null  object
#  5   Customer_Gender   113036 non-null  object
#  6   Country           113036 non-null  object
#  7   State             113036 non-null  object
#  8   Product_Category  113036 non-null  object
#  9   Sub_Category      113036 non-null  object
#  10  Product           113036 non-null  object
#  11  Order_Quantity    113036 non-null  int64
#  12  Unit_Cost         113036 non-null  int64
#  13  Unit_Price        113036 non-null  int64
#  14  Profit            113036 non-null  int64
#  15  Cost              113036 non-null  int64
# ...

# %%
sales.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
sales['Unit_Cost'].describe()
# Out:
# count    113036.000000
# mean        267.296366
# std         549.835483
# min           1.000000
# 25%           2.000000
# 50%           9.000000
# 75%          42.000000
# max        2171.000000
# Name: Unit_Cost, dtype: float64

# %%
sales['Unit_Cost'].mean()
# Out:
# np.float64(267.296365759581)

# %%
sales['Unit_Cost'].median()
# Out:
# np.float64(9.0)

# %%
sales['Unit_Cost'].plot(kind= 'box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
sales['Unit_Cost'].plot(kind='density', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
b = sales['Unit_Cost'].plot(kind='density', figsize=(14,6))
b.axvline(sales['Unit_Cost'].mean(), color='red')
b.axvline(sales['Unit_Cost'].median(), color='green')

# %%
b = sales['Unit_Cost'].plot(kind= 'hist', figsize=(14, 6))
b.set_ylabel('Number of Sales')
b.set_xlabel('dollars')
# Out:
# Text(0.5, 0, 'dollars')

# %%
b = sales['Unit_Cost'].plot(kind= 'hist', figsize=(14, 6))
b
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
sales['Age_Group'].value_counts()
# Out:
# Age_Group
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: count, dtype: int64

# %%
sales['Age_Group'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
b = sales['Age_Group'].value_counts().plot(kind='bar', figsize=(14,6))
b.set_ylabel('Number of sales')
b.set_xlabel('Age group')
# Out:
# Text(0.5, 0, 'Age group')

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
b = sales[['Day', 'Year', 'Customer_Age', 'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit', 'Cost', 'Revenue']]

b.corr()
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# ...

# %%
sales.select_dtypes(include=['int64','float64']).corr()
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# ...

# %%
corr = sales.select_dtypes(include=['int64','float64']).corr()

# %%
fig = plt.figure(figsize= (6,6))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
a = sales[['Customer_Age', 'Revenue']]
a.plot(kind='scatter', x='Customer_Age',y='Revenue',figsize=(8,8))
# Out:
# <Axes: xlabel='Customer_Age', ylabel='Revenue'>

# %%
sales.plot(kind='scatter', y='Revenue', x='Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Profit', ylabel='Revenue'>

# %%
ax = sales[['Age_Group', 'Profit']].boxplot(by='Age_Group', figsize=(10,6))
ax.set_ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
boxplot_col = ['Year', 'Customer_Age', 'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit']
sales[boxplot_col].plot(kind='box', subplots=True, layout=(2,3), figsize=(14,8))
# Out:
# Year                 Axes(0.125,0.53;0.227941x0.35)
# Customer_Age      Axes(0.398529,0.53;0.227941x0.35)
# Order_Quantity    Axes(0.672059,0.53;0.227941x0.35)
# Unit_Cost            Axes(0.125,0.11;0.227941x0.35)
# Unit_Price        Axes(0.398529,0.11;0.227941x0.35)
# Profit            Axes(0.672059,0.11;0.227941x0.35)
# dtype: object

# %% [markdown]
# sales['Revenue by Age'] = sales['Revenue']/ sales['Customer_Age']
#
# sales['Revenue by Age'].head()

# %%
sales['Revenue_by_Age'] = sales['Revenue'] / sales['Customer_Age']

sales['Revenue_by_Age'].head()
# Out:
# Date
# 2013-11-26    50.000000
# 2015-11-26    50.000000
# 2014-03-23    49.000000
# 2016-03-23    42.612245
# 2014-05-15     8.893617
# Name: Revenue_by_Age, dtype: float64

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
sales['Calculated_Cost'] = sales['Unit_Cost'] * sales['Order_Quantity']
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
 (sales['Calculated_Cost'] != sales['Cost']).sum()
# Out:
# np.int64(0)

# %%
sales.plot(kind='scatter', x='Profit', y='Calculated_Cost')
# Out:
# <Axes: xlabel='Profit', ylabel='Calculated_Cost'>

# %%
sales['Unit_Cost_Increase'] = sales['Unit_Cost'] * 1.03

sales['Unit_Cost_Increase'].head()
# Out:
# Date
# 2013-11-26    46.35
# 2015-11-26    46.35
# 2014-03-23    46.35
# 2016-03-23    46.35
# 2014-05-15    46.35
# Name: Unit_Cost_Increase, dtype: float64

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
sales.loc[sales['State']== 'Kentucky']
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-04    4  November  2013            40  Adults (35-64)               M
# 2015-11-04    4  November  2015            40  Adults (35-64)               M
# 2014-04-16   16     April  2014            40  Adults (35-64)               M
# 2016-04-16   16     April  2016            40  Adults (35-64)               M
# 2014-04-16   16     April  2014            40  Adults (35-64)               M
# 2016-04-16   16     April  2016            40  Adults (35-64)               M
# 2014-04-16   16     April  2014            40  Adults (35-64)               M
# 2014-04-16   16     April  2014            40  Adults (35-64)               M
# 2016-04-16   16     April  2016            40  Adults (35-64)               M
# 2016-04-16   16     April  2016            40  Adults (35-64)               M
#
#                   Country     State Product_Category     Sub_Category  \
# Date
# ...

# %%
sales.loc[sales['Age_Group'] == 'Adults (35-64)', 'Revenue'].mean()
# Out:
# np.float64(762.8287654055604)

# %%
sales.loc[(sales['Age_Group'] == 'Adults (35-64)') | (sales['Age_Group'] == 'Youth (<25)')].shape[0]
# Out:
# 73652

# %%
sales.loc[(sales['Age_Group'] == 'Adults (35-64)') & (sales['Country'] == 'United States'), 'Revenue'].mean()
# Out:
# np.float64(726.7260473588342)

# %%
sales.loc[sales['Country'] == 'France', 'Revenue']* 1.1
# Out:
# Date
# 2013-07-15     865.7
# 2015-07-15     865.7
# 2013-08-17    3252.7
# 2015-08-17    3136.1
# 2013-09-24     688.6
#                ...
# 2015-09-08    1892.0
# 2014-07-27     405.9
# 2016-07-27     473.0
# 2014-03-04    1386.0
# 2016-03-04    1327.7
# Name: Revenue, Length: 10998, dtype: float64

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
b = sales['Customer_Age'].plot(kind='density', figsize= (14,6))
b.set_ylabel('Density in decimal')
# Out:
# Text(0, 0.5, 'Density in decimal')

# %%
x = np.linspace(0, 10, 500)
y = np.cumsum(np.random.randn(500, 6), 0)

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='lower left')

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
sales.groupby(['Country', 'Customer_Gender']).agg({'Order_Quantity':'count', 'Profit': 'mean'})
# Out:
#                                 Order_Quantity      Profit
# Country        Customer_Gender
# Australia      F                         11506  299.225708
#                M                         12430  268.152776
# Canada         F                          6496  257.648091
#                M                          7682  266.026295
# France         F                          5504  252.460029
#                M                          5494  271.340007
# Germany        F                          5572  317.343324
#                M                          5526  288.048860
# United Kingdom F                          6712  329.172676
#                M                          6908  319.114939
# United States  F                         18934  277.284832
#                M                         20272  287.269781

# %%
sales.pivot_table(index='Customer_Gender', columns='Country', values='Profit', aggfunc='mean')
# Out:
# Country           Australia      Canada      France     Germany  \
# Customer_Gender
# F                299.225708  257.648091  252.460029  317.343324
# M                268.152776  266.026295  271.340007  288.048860
#
# Country          United Kingdom  United States
# Customer_Gender
# F                    329.172676     277.284832
# M                    319.114939     287.269781

# %%
sales[(sales['Customer_Gender']== 'M') & (sales['Customer_Age']>35) & (sales['Country']== 'Australia')]
# Out:
#             Day    Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2014-03-23   23    March  2014            49  Adults (35-64)               M
# 2016-03-23   23    March  2016            49  Adults (35-64)               M
# 2014-01-31   31  January  2014            44  Adults (35-64)               M
# 2016-01-31   31  January  2016            44  Adults (35-64)               M
# 2014-05-28   28      May  2014            44  Adults (35-64)               M
# ...         ...      ...   ...           ...             ...             ...
# 2016-01-16   16  January  2016            47  Adults (35-64)               M
# 2013-07-10   10     July  2013            54  Adults (35-64)               M
# 2015-07-10   10     July  2015            54  Adults (35-64)               M
# 2013-08-31   31   August  2013            54  Adults (35-64)               M
# 2015-08-31   31   August  2015            54  Adults (35-64)               M
#
# ...

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
plt.figure(figsize=(5,2))

plt.subplot(1,2,1)
sns.boxplot(x=sales[sales['Customer_Gender']== 'M']['Profit'])
plt.xticks(rotation='vertical')
plt.subplot(1,2,2)
sns.boxplot(x=sales[sales['Customer_Gender']== 'F']['Profit'])
plt.xticks(rotation='vertical')
# Out:
# (array([-2000.,     0.,  2000.,  4000.,  6000.]),
#  [Text(-2000.0, 0, '−2000'),
#   Text(0.0, 0, '0'),
#   Text(2000.0, 0, '2000'),
#   Text(4000.0, 0, '4000'),
#   Text(6000.0, 0, '6000')])

# %%
sns.boxplot(x= sales['Customer_Gender'], y= sales['Profit'])
# Out:
# <Axes: xlabel='Customer_Gender', ylabel='Profit'>

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
b = sales['Customer_Gender'].value_counts().reset_index()
b
# Out:
#   Customer_Gender  count
# 0               M  58312
# 1               F  54724

# %%
palette = {'M': 'brown', 'F': 'black'}
sns.barplot(x= b['Customer_Gender'], y= b['count'], palette=palette)

plt.ylabel('frequency')
plt.xlabel('gender')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6852\2208574107.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= b['Customer_Gender'], y= b['count'], palette=palette)
# Text(0.5, 0, 'gender')

# %%
b= sales.groupby('Country').agg({'Profit': 'mean'}).reset_index()

# %%
b
# Out:
#           Country      Profit
# 0       Australia  283.089489
# 1          Canada  262.187615
# 2          France  261.891435
# 3         Germany  302.756803
# 4  United Kingdom  324.071439
# 5   United States  282.447687

# %%
sns.barplot(x=b['Profit'], y=b['Country'])
# Out:
# <Axes: xlabel='Profit', ylabel='Country'>

# %%
palette = {'M': 'yellow', 'F': 'blue'}
sns.countplot(x=sales['Country'], hue=sales['Customer_Gender'], palette=palette)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113036 entries, 2013-11-26 to 2016-03-04
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Day                 113036 non-null  int64
#  1   Month               113036 non-null  object
#  2   Year                113036 non-null  int64
#  3   Customer_Age        113036 non-null  int64
#  4   Age_Group           113036 non-null  object
#  5   Customer_Gender     113036 non-null  object
#  6   Country             113036 non-null  object
#  7   State               113036 non-null  object
#  8   Product_Category    113036 non-null  object
#  9   Sub_Category        113036 non-null  object
#  10  Product             113036 non-null  object
#  11  Order_Quantity      113036 non-null  int64
#  12  Unit_Cost           113036 non-null  int64
#  13  Unit_Price          113036 non-null  int64
#  14  Profit              113036 non-null  int64
# ...

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...
